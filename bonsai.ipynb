# %%
import numpy as np
import pandas as pd

# %%
bonsai = pd.read_csv('Downloads/bonsai/bonsai_posts.csv')

# %%
bonsai
# Out:
#                        category    last_replier          poster  replies  \
# 0                      Help me!   manofthetrees            COYF     10.0
# 1                      Help me!       Youri1995            Luek      5.0
# 2                      Help me!             NaN        Lothar47      1.0
# 3                      Help me!   manofthetrees       BonsaiRob      5.0
# 4                      Help me!       Youri1995       skubicka2     10.0
# 5                      Help me!     Michel Buzz     unclepat_10      2.0
# 6              Basic techniques          Leslie          Leslie      4.0
# 7              Basic techniques     leatherback         Pinkham     13.0
# 8              Basic techniques   BassandBonsai          Leslie      5.0
# 9              Basic techniques         Artmyth         Artmyth      2.0
# 10             Basic techniques         Pinkham         Pinkham      7.0
# 11             Basic techniques     leatherback   babybirdsfunk     27.0
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
plt.hist(bonsai.replies)
# Out:
# (array([6.059e+03, 4.400e+01, 5.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  0.,  38.,  76., 114., 152., 190., 228., 266., 304., 342., 380.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(bonsai.views)
